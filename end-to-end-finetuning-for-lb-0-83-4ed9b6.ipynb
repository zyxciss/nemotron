# %% [markdown]
# # Nemotron finetuning pipeline

# %%
# ── Shared config ─────────────────────────────────────────────────────
LORA_RANK = 32
LORA_ALPHA = 32
LORA_DROPOUT = 0.0

MAX_SEQ_LEN = 8192
NUM_STEPS = 1000
BATCH_SIZE = 32
MICRO_BATCH_SIZE = 4
LEARNING_RATE = 2e-4
RESET_WEIGHTS = (
    True  # if True, skip loading pretrained adapter; train from fresh LoRA init
)
IN_PROJ_ONLY = False
MOE_TIE_WEIGHTS = True  # if True, tie one side of MoE expert LoRA across all 128 experts (Tinker-style)
ORIGINAL_PROBLEMS_ONLY = (
    False  # if True, filter examples to only problem_ids listed in train.csv
)
SHUFFLE_DATASET = False

KAGGLE_DATASET = "huikang/nemotron-data"
MINUTES = 60

TARGET_MODULES = [
    "q_proj",
    "k_proj",
    "v_proj",
    "o_proj",
    "up_proj",
    "down_proj",
    "in_proj",
    "out_proj",
    "lm_head",
]

# %%
import os

IS_KAGGLE = "KAGGLE_KERNEL_RUN_TYPE" in os.environ
IS_MODAL_WORKER = "MODAL_TASK_ID" in os.environ
IS_MODAL_LAUNCHER = not IS_KAGGLE and not IS_MODAL_WORKER

# %%
# ── Env-specific install (Kaggle only; Modal image has packages pre-installed) ──
if IS_KAGGLE:
    import subprocess

    subprocess.run(
        "pip install -q --no-index --find-links /kaggle/input/datasets/mayukh18/nemotron-packages/packages "
        "unsloth trl peft transformers datasets accelerate bitsandbytes",
        shell=True,
        check=True,
    )
    subprocess.run(
        "pip install -q /kaggle/input/datasets/mayukh18/nemotron-packages/causal_conv1d-1.6.1+cu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl",
        shell=True,
        check=True,
    )
    subprocess.run(
        "pip install -q /kaggle/input/datasets/mayukh18/nemotron-packages/mamba_ssm-2.3.1+cu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl",
        shell=True,
        check=True,
    )
    for _wd in ["/kaggle/input/datasets/llkh0a/rtx-wheels/wheels"]:
        if os.path.isdir(_wd):
            subprocess.run(
                [
                    "pip",
                    "install",
                    "-q",
                    "--no-index",
                    "--find-links",
                    _wd,
                    "protobuf==6.33.5",
                    "sentencepiece",
                    "safetensors",
                    "huggingface_hub",
                ],
                check=False,
            )
    subprocess.run("rm -rf /kaggle/tmp/*", shell=True, check=True)
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# s3fs 2026.2.0 requires fsspec==2026.2.0, but you have fsspec 2025.9.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.5 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.5 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.5 which is incompatible.

# %%
def run_training() -> None:
    """Full training flow. Runs on Kaggle at module level or inside Modal container via train_remote()."""
    import gc
    import json
    import math
    import random
    import subprocess
    import sys
    import time

    from unsloth import FastLanguageModel

    import torch
    from cut_cross_entropy import linear_cross_entropy
    from peft import LoraConfig
    from peft.tuners.lora import Linear as LoraLinear

    # ── Env-specific paths + adapter source ──────────────────────────
    if IS_KAGGLE:
        import kagglehub

        CORPUS_PATH = "/kaggle/input/datasets/tahaalam2009/nemotron-data/nemotron/tokens"
        TRAIN_ORDER_PATH = "/kaggle/input/datasets/tahaalam2009/nemotron-data/nemotron/logprobs/index.jsonl"
        TRAIN_CSV_PATH = "/kaggle/input/competitions/nvidia-nemotron-model-reasoning-challenge/train.csv"
        ADAPTER_SRC = "/kaggle/tmp/pretrained_adapter"
        if not RESET_WEIGHTS:
            import zipfile as _zipfile

            _adapter_zip = "/kaggle/input/notebooks/huikang/tinker-submission-notebook/submission.zip"
            os.makedirs(ADAPTER_SRC, exist_ok=True)
            with _zipfile.ZipFile(_adapter_zip, "r") as _zf:
                _zf.extractall(ADAPTER_SRC)
        MODEL_PATH = kagglehub.model_download(
            "metric/nemotron-3-nano-30b-a3b-bf16/transformers/default"
        )
    else:  # IS_MODAL_WORKER
        MODEL_PATH = "unsloth/Nemotron-3-Nano-30B-A3B"
        CORPUS_PATH = "/data/corpus_preprocessed.jsonl"
        TRAIN_CSV_PATH = "/data/train.csv"
        ADAPTER_SRC = "/merged/weights"
        OUTPUT_DIR = "/output/weights"

    # ── GPU + kernel sanity check (runs on both Kaggle and Modal worker) ──
    import causal_conv1d
    import mamba_ssm

    cc = torch.cuda.get_device_capability(0)
    print(f"GPU: {torch.cuda.get_device_name(0)}, sm_{cc[0] * 10 + cc[1]}")
    print(f"torch={torch.__version__}, cuda={torch.version.cuda}")
    print(
        f"mamba_ssm={mamba_ssm.__version__}, causal_conv1d={causal_conv1d.__version__}"
    )
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    if IS_MODAL_WORKER:
        assert cc == (12, 0), (
            f"Expected sm_120 (RTX PRO 6000), got sm_{cc[0] * 10 + cc[1]}"
        )
    from causal_conv1d import causal_conv1d_fn

    _x = torch.randn(1, 256, 32, device="cuda", dtype=torch.bfloat16)
    _w = torch.randn(256, 4, device="cuda", dtype=torch.bfloat16)
    causal_conv1d_fn(_x, _w, None, activation="silu")
    print("causal_conv1d CUDA kernel: OK")

    # Clear stale HF modules cache (Modal-only; bug: persists across runs)
    if IS_MODAL_WORKER:
        import shutil as _shutil

        hf_modules = os.path.join(
            os.environ.get("HF_HOME", "/root/.cache/huggingface"), "modules"
        )
        if os.path.exists(hf_modules):
            _shutil.rmtree(hf_modules)

    # ── Load corpus into `examples` list ─────────────────────────────
    examples: list[dict] = []

    if IS_KAGGLE:
        # Load problem_ids in training order from logprobs/index.jsonl (epoch 0).
        # Each entry has {epoch, step, problem_id, ...}; epoch-0 entries are the
        # original training order, which we replay here.
        ordered_ids: list[str] = []
        seen: set[str] = set()
        with open(TRAIN_ORDER_PATH) as f:
            for line in f:
                rec = json.loads(line)
                if rec.get("epoch", 0) != 0:
                    continue
                pid = rec["problem_id"]
                if pid in seen:
                    continue
                seen.add(pid)
                ordered_ids.append(pid)
        print(
            f"Loaded {len(ordered_ids)} problem_ids in training order from "
            f"{TRAIN_ORDER_PATH}"
        )

        for sid in ordered_ids:
            seg_path = os.path.join(CORPUS_PATH, sid, "synthetic.json")
            assert os.path.isfile(seg_path), (
                f"problem_id {sid} from training order missing in corpus: {seg_path}"
            )
            with open(seg_path) as f:
                rec = json.load(f)
            tokens = rec["tokens"]
            mask = rec["mask"]
            if not tokens:
                continue
            if len(tokens) > MAX_SEQ_LEN:
                tokens = tokens[:MAX_SEQ_LEN]
                mask = mask[:MAX_SEQ_LEN]
            if not any(mask):
                continue
            examples.append(
                {
                    "problem_id": sid,
                    "tokens": tokens[:-1],
                    "targets": tokens[1:],
                    "weights": [float(m) for m in mask[1:]],
                }
            )
    else:  # IS_MODAL_WORKER
        with open(CORPUS_PATH) as f:
            for line in f:
                rec = json.loads(line.strip())
                tokens = rec["tokens"]
                mask = rec["mask"]
                if len(tokens) > MAX_SEQ_LEN:
                    tokens = tokens[:MAX_SEQ_LEN]
                    mask = mask[:MAX_SEQ_LEN]
                if not any(mask):
                    continue
                examples.append(
                    {
                        "problem_id": rec["problem_id"],
                        "tokens": tokens[:-1],
                        "targets": tokens[1:],
                        "weights": [float(m) for m in mask[1:]],
                    }
                )

    if ORIGINAL_PROBLEMS_ONLY:
        import csv

        with open(TRAIN_CSV_PATH) as f:
            original_ids = {row["id"] for row in csv.DictReader(f)}
        before = len(examples)
        examples = [e for e in examples if e["problem_id"] in original_ids]
        print(
            f"ORIGINAL_PROBLEMS_ONLY=True: filtered {before} → {len(examples)} examples "
            f"using {len(original_ids)} ids from {TRAIN_CSV_PATH}"
        )

    total_unmasked = sum(sum(e["weights"]) for e in examples)
    total_tokens = sum(len(e["tokens"]) for e in examples)
    print(
        f"Loaded {len(examples)} examples, {total_tokens:,} tokens "
        f"(unmasked={total_unmasked:,.0f})"
    )

    # ── Load base model ──────────────────────────────────────────────
    gc.collect()
    torch.cuda.empty_cache()

    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=MODEL_PATH,
        max_seq_length=MAX_SEQ_LEN,
        load_in_4bit=False,
        load_in_8bit=False,
        full_finetuning=False,
        trust_remote_code=True,
        unsloth_force_compile=True,
        attn_implementation="eager",
        dtype=torch.bfloat16,
    )
    if IS_MODAL_WORKER:
        hf_cache_vol.commit()  # noqa: F821 — defined at module level on non-Kaggle

    # ── Wrap in LoRA ─────────────────────────────────────────────────
    model = FastLanguageModel.get_peft_model(
        model,
        r=LORA_RANK,
        target_modules=TARGET_MODULES,
        lora_alpha=LORA_ALPHA,
        lora_dropout=LORA_DROPOUT,
        bias="none",
        use_gradient_checkpointing="unsloth",
        random_state=42,
    )
    FastLanguageModel.for_training(model)

    # ── Patch Mamba CUDA fast path ───────────────────────────────────
    nemotron_mod = None
    for _name, _m in sys.modules.items():
        if "modeling_nemotron_h" in _name and hasattr(_m, "is_fast_path_available"):
            nemotron_mod = _m
            break
    assert nemotron_mod is not None, "Could not find modeling_nemotron_h module"
    print(f"is_fast_path_available was: {nemotron_mod.is_fast_path_available}")
    nemotron_mod.is_fast_path_available = True  # type: ignore[attr-defined]
    print("Patched is_fast_path_available = True")

    # ── Manually add lm_head LoRA (Unsloth drops it for MoE) ─────────
    _causal_lm = model
    while hasattr(_causal_lm, "model"):
        _causal_lm = _causal_lm.model
    _lm_head = _causal_lm.lm_head
    if not isinstance(_lm_head, LoraLinear):
        _cfg = LoraConfig(r=LORA_RANK, lora_alpha=LORA_ALPHA, lora_dropout=LORA_DROPOUT)
        model.base_model._create_and_replace(
            _cfg,
            "default",
            target=_lm_head,
            target_name="lm_head",
            parent=_causal_lm,
        )
        print("Manually added LoRA to lm_head")
    else:
        print("lm_head already has LoRA")

    # ── Cast LoRA params to fp32 (base model stays bf16 except MoE router) ──
    for name, param in model.named_parameters():
        if ".lora_" in name:
            param.data = param.data.to(torch.float32)

    for name, param in model.named_parameters():
        if ".lora_" in name:
            assert param.dtype == torch.float32, (
                f"LoRA param {name} expected fp32, got {param.dtype}"
            )
            continue

        is_router = (
            ".mixer.gate." in name
        )  # NemotronHTopkRouter.weight + e_score_correction_bias
        # Nemotron-H loads the MoE router (`mixer.gate`) in fp32 on purpose.
        # Ref: transformers/src/transformers/models/nemotron_h/modeling_nemotron_h.py
        #
        #   class NemotronHPreTrainedModel(PreTrainedModel):
        #       _keep_in_fp32_modules_strict = ["e_score_correction_bias"]
        #
        #   class NemotronHTopkRouter(nn.Module):
        #       def __init__(self, config):
        #           self.weight = nn.Parameter(torch.empty((self.n_routed_experts, config.hidden_size)))
        #           self.register_buffer("e_score_correction_bias", torch.zeros(self.n_routed_experts))
        #       def forward(self, hidden_states):
        #           router_logits = F.linear(
        #               hidden_states.type(torch.float32),
        #               self.weight.type(torch.float32),
        #           )
        #           return router_logits
        #
        # The per-forward fp32 cast on `self.weight` plus the strict list entry
        # mean the gate weight is promoted to fp32 at load time.
        if is_router:
            assert param.dtype == torch.float32, (
                f"param {name} expected fp32, got {param.dtype}"
            )
            continue

        assert param.dtype == torch.bfloat16, (
            f"param {name} expected bf16, got {param.dtype}"
        )
        continue

    print("Verified: LoRA params fp32, base params bf16 (MoE router fp32)")

    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    total = sum(p.numel() for p in model.parameters())
    print(f"Model: {trainable:,} trainable / {total:,} total parameters")

    # ── Patch forward with Cut Cross-Entropy ─────────────────────────
    _base = model
    while hasattr(_base, "model"):
        _base = _base.model

    def _patched_causal_forward(
        input_ids=None, attention_mask=None, labels=None, **kwargs
    ):
        backbone_out = _base.backbone(
            input_ids=input_ids,
            attention_mask=attention_mask,
            **{
                k: v
                for k, v in kwargs.items()
                if k in ("position_ids", "past_key_values", "use_cache")
            },
        )
        hidden_states = backbone_out[0]
        lm_head = _base.lm_head
        base_w = lm_head.base_layer.weight
        lora_A = lm_head.lora_A["default"].weight
        lora_B = lm_head.lora_B["default"].weight
        scaling = lm_head.scaling["default"]
        lm_weight = base_w + scaling * lora_B @ lora_A
        if labels is not None:
            per_token_ce = linear_cross_entropy(
                hidden_states, lm_weight, labels, reduction="none"
            )
            loss = per_token_ce.mean()
        else:
            per_token_ce = None
            loss = None
        model._cached_per_token_ce = per_token_ce  # type: ignore[attr-defined]
        return loss

    _base.forward = _patched_causal_forward
    print("Patched CausalLM.forward with CCE (no logits materialization)")

    # ── Load adapter weights (unless RESET_WEIGHTS) ──────────────────
    if RESET_WEIGHTS:
        print(
            "RESET_WEIGHTS=True — skipping pretrained adapter load; using fresh LoRA init"
        )
        loaded = 0
        adapter_weights: dict = {}
    else:
        print(f"Loading adapter from {ADAPTER_SRC}...")
        from peft import load_peft_weights

        adapter_weights = load_peft_weights(ADAPTER_SRC)

        model_sd = model.state_dict()
        new_sd: dict = {}
        loaded = 0
        for ak, av in adapter_weights.items():
            if ak in model_sd:
                new_sd[ak] = av
                loaded += 1
                continue
            ak_with_default = ak.replace(
                ".lora_A.weight", ".lora_A.default.weight"
            ).replace(".lora_B.weight", ".lora_B.default.weight")
            if ak_with_default in model_sd:
                new_sd[ak_with_default] = av
                loaded += 1
                continue
            ak_lm = ak.replace(".backbone.lm_head.", ".lm_head.")
            ak_lm_default = ak_lm.replace(
                ".lora_A.weight", ".lora_A.default.weight"
            ).replace(".lora_B.weight", ".lora_B.default.weight")
            if ak_lm_default in model_sd:
                new_sd[ak_lm_default] = av
                loaded += 1
                continue

        model.load_state_dict(new_sd, strict=False)
        assert loaded == len(adapter_weights), (
            f"Not all adapter weights loaded: {loaded}/{len(adapter_weights)}"
        )
        print(f"  Loaded {loaded}/{len(adapter_weights)} weights into model")

    # ── Freeze all LoRA params except in_proj (if IN_PROJ_ONLY) ──
    print(f"{IN_PROJ_ONLY=}")
    if IN_PROJ_ONLY:
        for name, param in model.named_parameters():
            if param.requires_grad and ".in_proj." not in name:
                param.requires_grad = False
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    frozen_params = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    print(f"  {trainable_params:,} trainable / {frozen_params:,} frozen")

    # ── MoE tied-weight params (Tinker convention) ───────────────────
    # Tinker ties whichever LoRA side touches the hidden dim:
    #   gate_up_proj / up_proj / w1 / gate_proj  -> tie A (input/hidden side)
    #   down_proj / w2                           -> tie B (output/hidden side)
    # We keep Unsloth's batched [num_experts, ...] tensor layout; "tying" means
    # all 128 expert slices are kept identical. Saving the adapter naturally
    # emits 128 per-expert copies, so submission.zip is untied downstream.
    moe_tied_params: list[torch.Tensor] = []
    if MOE_TIE_WEIGHTS:
        w1_proj_names = ("gate_up_proj", "up_proj", "gate_proj", ".w1.")
        w2_proj_names = ("down_proj", ".w2.")
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            if ".experts." not in name or ".lora_" not in name:
                continue
            is_w1 = any(p in name for p in w1_proj_names)
            is_w2 = any(p in name for p in w2_proj_names)
            is_A = ".lora_A." in name
            is_B = ".lora_B." in name
            should_tie = (is_w1 and is_A) or (is_w2 and is_B)
            if not should_tie:
                continue
            if param.dim() < 2 or param.shape[0] <= 1:
                continue
            moe_tied_params.append(param)

        def _tie_param_init() -> None:
            """Make all 128 expert slices identical (mean-and-broadcast)."""
            with torch.no_grad():
                for p in moe_tied_params:
                    mean = p.data.mean(dim=0, keepdim=True)
                    p.data.copy_(mean.expand_as(p.data))

        def _tie_grads() -> None:
            # Sum (not mean) across the expert dim: if W is the shared LoRA factor
            # and each expert uses a copy W_i = W, chain rule gives
            # dL/dW = sum_i dL/dW_i. Inactive experts contribute 0 and router
            # weights are already baked into active g_i, so there's no
            # double-counting. Summing keeps all 128 slices identical after each
            # AdamW step and reproduces the true shared-weight update; mean would
            # be off by a 1/128 lr rescale (and not exactly equivalent under
            # AdamW's eps/weight-decay).
            with torch.no_grad():
                for p in moe_tied_params:
                    if p.grad is None:
                        continue
                    grad_sum = p.grad.sum(dim=0, keepdim=True)
                    p.grad.copy_(grad_sum.expand_as(p.grad))

        print(f"MoE weight tying: {len(moe_tied_params)} params identified for tying")
        if moe_tied_params:
            print(f"  example shapes: {[tuple(p.shape) for p in moe_tied_params[:3]]}")
        _tie_param_init()  # start from a tied state
    else:

        def _tie_grads() -> None:
            pass

    # ── Training loop ────────────────────────────────────────────────
    gc.collect()
    torch.cuda.empty_cache()

    device = next(model.parameters()).device
    optimizer: torch.optim.AdamW | None = None

    indices = list(range(len(examples)))
    if SHUFFLE_DATASET:
        rng = random.Random(0)
        rng.shuffle(indices)
        print(f"SHUFFLE_DATASET=True: shuffled {len(indices)} examples (seed=0)")
    else:
        print(f"SHUFFLE_DATASET=False: keeping corpus order ({len(indices)} examples)")

    training_log: list[str] = []

    def _log(msg: str) -> None:
        print(msg, flush=True)
        training_log.append(msg)

    max_steps = len(examples) // BATCH_SIZE
    num_steps = NUM_STEPS
    if num_steps > max_steps:
        _log(
            f"WARNING: NUM_STEPS={NUM_STEPS} exceeds max_steps={max_steps} "
            f"({len(examples)} examples // {BATCH_SIZE} batch). Clamping to {max_steps}."
        )
        num_steps = max_steps

    _log(
        f"Training: {num_steps} steps, batch_size={BATCH_SIZE}, "
        f"micro_batch_size={MICRO_BATCH_SIZE}, lr={LEARNING_RATE}"
    )

    step = 0
    for batch_start in range(0, len(indices), BATCH_SIZE):
        if step >= num_steps:
            break
        batch_indices = indices[batch_start : batch_start + BATCH_SIZE]
        batch = [examples[i] for i in batch_indices]
        batch_tokens = [e["tokens"] for e in batch]
        batch_targets = [e["targets"] for e in batch]
        batch_weights = [e["weights"] for e in batch]

        n = len(batch)
        n_accum = math.ceil(n / MICRO_BATCH_SIZE)
        total_loss_sum = 0.0
        total_weight_sum = 0.0

        for mb_start in range(0, n, MICRO_BATCH_SIZE):
            mb_end = min(mb_start + MICRO_BATCH_SIZE, n)
            mb_toks = batch_tokens[mb_start:mb_end]
            mb_tgts = batch_targets[mb_start:mb_end]
            mb_wts = batch_weights[mb_start:mb_end]

            n_micro = len(mb_toks)
            max_len = max(len(t) for t in mb_toks)
            total_len = sum(len(t) for t in mb_toks)

            padded_input = torch.zeros(
                n_micro, max_len, dtype=torch.long, device=device
            )
            padded_targets = torch.zeros(
                n_micro, max_len, dtype=torch.long, device=device
            )
            padded_weights = torch.zeros(
                n_micro, max_len, dtype=torch.float32, device=device
            )
            attention_mask = torch.zeros(
                n_micro, max_len, dtype=torch.long, device=device
            )
            for i in range(n_micro):
                seq_len = len(mb_toks[i])
                padded_input[i, :seq_len] = torch.tensor(mb_toks[i], dtype=torch.long)
                padded_targets[i, :seq_len] = torch.tensor(mb_tgts[i], dtype=torch.long)
                padded_weights[i, :seq_len] = torch.tensor(
                    mb_wts[i], dtype=torch.float32
                )
                attention_mask[i, :seq_len] = 1

            t0 = time.time()
            with torch.amp.autocast("cuda", dtype=torch.bfloat16):
                model(
                    input_ids=padded_input,
                    attention_mask=attention_mask,
                    labels=padded_targets,
                    use_cache=False,
                )
                per_token_ce = model._cached_per_token_ce  # type: ignore[attr-defined]
                weighted_loss = per_token_ce * padded_weights
                weight_sum_t = padded_weights.sum()
                loss_sum_t = weighted_loss.sum()
                loss = (
                    loss_sum_t / weight_sum_t if weight_sum_t > 0 else loss_sum_t * 0.0
                )

            (loss / n_accum).backward()
            total_loss_sum += loss_sum_t.item()
            total_weight_sum += weight_sum_t.item()
            del loss, per_token_ce, weighted_loss

            t_end = time.time()
            peak_gb = torch.cuda.max_memory_allocated() / 1e9
            mem_gb = torch.cuda.memory_allocated() / 1e9
            mb_idx = mb_start // MICRO_BATCH_SIZE
            print(
                f"    micro-batch {mb_idx}: {n_micro} seqs, max_len={max_len}, "
                f"total_len={total_len}, wall={t_end - t0:.1f}s, "
                f"peak={peak_gb:.1f}GB, mem={mem_gb:.1f}GB"
            )

        if optimizer is None:
            optimizer = torch.optim.AdamW(
                [p for p in model.parameters() if p.requires_grad],
                lr=LEARNING_RATE,
                betas=(0.9, 0.95),
                eps=1e-8,
                weight_decay=0.0,
            )
        lr = LEARNING_RATE * (1 - step / num_steps)
        for pg in optimizer.param_groups:
            pg["lr"] = lr
        _tie_grads()  # average MoE expert grads before clip+step so Adam stays in sync
        grad_norm = torch.nn.utils.clip_grad_norm_(
            [p for p in model.parameters() if p.requires_grad], max_norm=1e9
        )
        optimizer.step()
        optimizer.zero_grad()
        loss_mean = total_loss_sum / total_weight_sum if total_weight_sum > 0 else 0
        step += 1
        _log(
            f"  step {step}/{num_steps}: "
            f"loss:mean={loss_mean:.6f}, grad_norm={grad_norm:.4f}, lr={lr:.2e}"
        )

    print(
        f"\nTraining complete. Peak VRAM: {torch.cuda.max_memory_allocated() / 1e9:.1f} GB"
    )

    # ── Save adapter + rename lm_head keys (identical on both sides) ──
    from safetensors.torch import load_file, save_file

    save_dir = "." if IS_KAGGLE else OUTPUT_DIR
    os.makedirs(save_dir, exist_ok=True)
    for _f in os.listdir(save_dir):
        if _f.startswith("adapter"):
            os.remove(os.path.join(save_dir, _f))
    model.save_pretrained(save_dir)
    st_path = os.path.join(save_dir, "adapter_model.safetensors")
    tensors = load_file(st_path)
    renamed = {
        k.replace("base_model.model.lm_head.", "base_model.model.backbone.lm_head."): v
        for k, v in tensors.items()
    }
    save_file(renamed, st_path)

    # ── Clean unsloth compiled cache (runs on both) ──────────────────
    _ucache = "unsloth_compiled_cache"
    if os.path.isdir(_ucache):
        import shutil as _sh

        _sh.rmtree(_ucache)

    # ── Package & ship (divergent) ───────────────────────────────────
    if IS_KAGGLE:
        import zipfile

        adapter_files = [f for f in os.listdir(save_dir) if f.startswith("adapter")]
        SUBMISSION_ZIP = "submission.zip"
        with zipfile.ZipFile(SUBMISSION_ZIP, "w", zipfile.ZIP_DEFLATED) as zf:
            for fname in adapter_files:
                zf.write(os.path.join(save_dir, fname), fname)
        for fname in adapter_files:
            os.remove(os.path.join(save_dir, fname))
        print(f"Wrote {SUBMISSION_ZIP}")
    else:  # IS_MODAL_WORKER
        import shutil
        import tempfile

        with open(os.path.join(save_dir, "training_log.txt"), "w") as f:
            f.write("\n".join(training_log) + "\n")
        output_vol.commit()  # noqa: F821 — defined at module level on non-Kaggle

        kaggle_dir = os.path.expanduser("~/.kaggle")
        os.makedirs(kaggle_dir, exist_ok=True)
        with open(os.path.join(kaggle_dir, "access_token"), "w") as f:
            f.write(os.environ["KAGGLE_API_TOKEN"])
        upload_dir = tempfile.mkdtemp()
        for fname in os.listdir(save_dir):
            shutil.copy(os.path.join(save_dir, fname), upload_dir)
        metadata = {"id": KAGGLE_DATASET, "title": KAGGLE_DATASET.split("/")[1]}
        with open(os.path.join(upload_dir, "dataset-metadata.json"), "w") as f:
            json.dump(metadata, f)
        print(f"Uploading to Kaggle {KAGGLE_DATASET}...")
        subprocess.run(
            [
                "kaggle",
                "datasets",
                "version",
                "-p",
                upload_dir,
                "-m",
                "post-finetuned adapter + compiled wheels",
            ],
            check=True,
        )
        print("Kaggle upload complete.")
    print("Training complete.")

# %%
# ── Modal glue: image, app, volumes, train_remote, main ──────────────
# Defined at module level on non-Kaggle so the worker's module import
# registers train_remote with the app. On Kaggle, skipped entirely
# (modal package is not installed there).
if not IS_KAGGLE:
    import modal

    train_image = (
        modal.Image.from_registry(
            "nvidia/cuda:12.8.1-devel-ubuntu22.04",
            add_python="3.12",
        )
        .entrypoint([])
        .apt_install("git", "build-essential", "clang")
        .pip_install(
            "torch==2.10.0",
            extra_index_url="https://download.pytorch.org/whl/cu128",
        )
        .pip_install(
            "safetensors>=0.5.0",
            "transformers>=4.56.2",
            "accelerate>=1.0.0",
            "peft>=0.15.0",
            "bitsandbytes>=0.45.0",
            "huggingface_hub>=0.36.2",
            "hf-transfer>=0.1.9",
            "numpy",
            "pillow",
            "torchvision",
            "datasets",
            "sentencepiece",
            "xformers",
            "cut-cross-entropy>=25.1.0",
            "wheel",
            "setuptools",
            "trl",
            "kaggle>=1.6.0",
        )
        .run_commands(
            'python -c "import torch.utils.cpp_extension as e; p=e.__file__; '
            "t=open(p).read().replace('raise RuntimeError(CUDA_MISMATCH_MESSAGE', 'pass  # '); "
            "open(p,'w').write(t)\"",
            "TORCH_CUDA_ARCH_LIST='12.0' pip wheel --no-build-isolation --wheel-dir /wheels mamba_ssm==2.3.1 causal_conv1d==1.6.1",
            "pip install --no-deps /wheels/mamba_ssm-*.whl /wheels/causal_conv1d-*.whl",
            "pip install --no-deps 'unsloth_zoo[base] @ git+https://github.com/unslothai/unsloth-zoo'",
            "pip install --no-deps 'unsloth[base] @ git+https://github.com/unslothai/unsloth'",
        )
        .pip_install("einops")
        .env({"HF_HOME": "/root/.cache/huggingface"})
    )

    hf_cache_vol = modal.Volume.from_name("huggingface-cache", create_if_missing=True)
    merged_vol = modal.Volume.from_name("merged-adapter", create_if_missing=True)
    corpus_vol = modal.Volume.from_name("corpus-data", create_if_missing=True)
    output_vol = modal.Volume.from_name("post-finetune-output", create_if_missing=True)

    app = modal.App("post-finetune-pipeline")

    @app.function(
        image=train_image,
        gpu="RTX-PRO-6000",
        volumes={
            "/root/.cache/huggingface": hf_cache_vol,
            "/merged": merged_vol,
            "/data": corpus_vol,
            "/output": output_vol,
        },
        timeout=6 * 60 * MINUTES,
        secrets=[modal.Secret.from_local_environ(["KAGGLE_API_TOKEN"])],
    )
    def train_remote() -> None:
        run_training()

    if IS_MODAL_LAUNCHER:

        @app.local_entrypoint()
        def main() -> None:
            train_remote.remote()

# %%
# On Kaggle, trigger training directly after cells load.
# On Modal worker, Modal's runtime calls train_remote() which calls run_training().
# On Modal launcher, neither fires (main() submits the remote call instead).
if IS_KAGGLE:
    run_training()
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2026-05-27 07:46:57.471917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779868017.642833      65 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779868017.691821      65 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779868018.141618      65 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779868018.141634      65 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779868018.141635      65 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779868018.141636      65 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition, sm_120
# torch=2.10.0+cu128, cuda=12.8
# mamba_ssm=2.3.1, causal_conv1d=1.6.1
# VRAM: 102.0 GB
# causal_conv1d CUDA kernel: OK
# Loaded 7830 problem_ids in training order from /kaggle/input/datasets/tahaalam2009/nemotron-data/nemotron/logprobs/index.jsonl
# Loaded 7830 examples, 30,522,712 tokens (unmasked=29,248,646)
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.3.17: Fast Nemotron_H patching. Transformers: 4.57.6.
#    \\   /|    NVIDIA RTX PRO 6000 Blackwell Server Edition. Num GPUs = 1. Max memory: 94.971 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 12.0. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# Loading checkpoint shards:   0%|          | 0/13 [00:00<?, ?it/s]
# /kaggle/input/models/metric/nemotron-3-nano-30b-a3b-bf16/transformers/default/1 does not have a padding token! Will use pad_token = <SPECIAL_999>.
# Unsloth: Detected MoE model with num_experts = 128 and target_modules = ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'up_proj', 'down_proj', 'in_proj', 'out_proj', 'lm_head']. Enabling LoRA on MoE parameters: ['mlp.experts.gate_up_proj', 'mlp.experts.down_proj']
# Unsloth: PEFT set target_parameters but found no matching parameters.
# This is expected for MoE models - Unsloth handles MoE expert LoRA targeting separately.
# Unsloth: Making `model.base_model.model.backbone` require gradients
# is_fast_path_available was: True
# Patched is_fast_path_available = True
# lm_head already has LoRA
# Verified: LoRA params fp32, base params bf16 (MoE router fp32)
# Model: 888,154,112 trainable / 32,466,091,456 total parameters
# Patched CausalLM.forward with CCE (no logits materialization)
# RESET_WEIGHTS=True — skipping pretrained adapter load; using fresh LoRA init
# IN_PROJ_ONLY=False
#   888,154,112 trainable / 31,577,937,344 frozen
# MoE weight tying: 5888 params identified for tying
#   example shapes: [(32, 2688), (2688, 32), (32, 2688)]
# SHUFFLE_DATASET=False: keeping corpus order (7830 examples)
# WARNING: NUM_STEPS=1000 exceeds max_steps=244 (7830 examples // 32 batch). Clamping to 244.
# Training: 244 steps, batch_size=32, micro_batch_size=4, lr=0.0002
# Unsloth: Will smartly offload gradients to save VRAM!
#     micro-batch 0: 4 seqs, max_len=7613, total_len=17867, wall=61.3s, peak=79.7GB, mem=70.8GB
#     micro-batch 1: 4 seqs, max_len=3386, total_len=6938, wall=4.0s, peak=79.7GB, mem=70.6GB
#     micro-batch 2: 4 seqs, max_len=3753, total_len=8904, wall=4.4s, peak=79.7GB, mem=70.6GB
#     micro-batch 3: 4 seqs, max_len=6357, total_len=17973, wall=6.3s, peak=79.7GB, mem=70.7GB
#     micro-batch 4: 4 seqs, max_len=4038, total_len=10739, wall=4.9s, peak=79.7GB, mem=70.6GB
#     micro-batch 5: 4 seqs, max_len=6569, total_len=11109, wall=6.5s, peak=79.7GB, mem=70.7GB
#     micro-batch 6: 4 seqs, max_len=6732, total_len=18841, wall=8.2s, peak=79.7GB, mem=70.7GB
#     micro-batch 7: 4 seqs, max_len=6793, total_len=24011, wall=6.6s, peak=79.7GB, mem=70.7GB
#   step 1/244: loss:mean=0.380814, grad_norm=1.3066, lr=2.00e-04
#     micro-batch 0: 4 seqs, max_len=3290, total_len=7977, wall=3.9s, peak=81.4GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=6855, total_len=16485, wall=6.7s, peak=86.4GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6647, total_len=9372, wall=6.9s, peak=86.4GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7688, total_len=19372, wall=7.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2902, total_len=7189, wall=3.7s, peak=87.5GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=6984, total_len=14047, wall=6.8s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6570, total_len=17294, wall=6.5s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7402, total_len=13147, wall=7.1s, peak=87.5GB, mem=77.8GB
#   step 2/244: loss:mean=0.439568, grad_norm=1.3657, lr=1.99e-04
#     micro-batch 0: 4 seqs, max_len=6198, total_len=8792, wall=6.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7642, total_len=19503, wall=7.3s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6930, total_len=19337, wall=6.8s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6226, total_len=18710, wall=6.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7420, total_len=18410, wall=8.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7656, total_len=25579, wall=7.7s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6677, total_len=20951, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6408, total_len=18345, wall=6.4s, peak=87.5GB, mem=77.8GB
#   step 3/244: loss:mean=0.368085, grad_norm=0.7465, lr=1.98e-04
#     micro-batch 0: 4 seqs, max_len=6527, total_len=20201, wall=6.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7283, total_len=14953, wall=7.0s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6264, total_len=19565, wall=6.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7571, total_len=24111, wall=7.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7275, total_len=16549, wall=7.0s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=3495, total_len=10315, wall=4.1s, peak=87.5GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=7128, total_len=13077, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7304, total_len=21094, wall=7.0s, peak=87.5GB, mem=77.8GB
#   step 4/244: loss:mean=0.297132, grad_norm=0.5467, lr=1.98e-04
#     micro-batch 0: 4 seqs, max_len=1124, total_len=4324, wall=2.9s, peak=87.5GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7681, total_len=20938, wall=7.3s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6286, total_len=10931, wall=6.3s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6444, total_len=17685, wall=6.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7573, total_len=18123, wall=7.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6505, total_len=12911, wall=6.5s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7250, total_len=21991, wall=7.0s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=1119, total_len=3625, wall=2.8s, peak=87.5GB, mem=77.6GB
#   step 5/244: loss:mean=0.327924, grad_norm=0.6378, lr=1.97e-04
#     micro-batch 0: 4 seqs, max_len=6715, total_len=15703, wall=7.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7460, total_len=15158, wall=7.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3887, total_len=8115, wall=4.4s, peak=87.5GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6405, total_len=18870, wall=6.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6779, total_len=14686, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6921, total_len=15356, wall=6.8s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=3999, total_len=10477, wall=4.5s, peak=87.5GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=7063, total_len=14676, wall=6.9s, peak=87.5GB, mem=77.8GB
#   step 6/244: loss:mean=0.273154, grad_norm=0.5304, lr=1.96e-04
#     micro-batch 0: 4 seqs, max_len=7336, total_len=16481, wall=7.0s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7418, total_len=19593, wall=7.1s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7295, total_len=18524, wall=7.0s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=4288, total_len=9588, wall=8.9s, peak=87.5GB, mem=77.7GB
#     micro-batch 4: 4 seqs, max_len=4141, total_len=10703, wall=4.6s, peak=87.5GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=5756, total_len=9895, wall=5.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7362, total_len=18267, wall=7.1s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7583, total_len=17301, wall=7.3s, peak=87.5GB, mem=77.8GB
#   step 7/244: loss:mean=0.273326, grad_norm=0.5122, lr=1.95e-04
#     micro-batch 0: 4 seqs, max_len=7562, total_len=16269, wall=7.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7138, total_len=19626, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=4663, total_len=12692, wall=6.0s, peak=87.5GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6137, total_len=9005, wall=6.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=3365, total_len=6088, wall=4.1s, peak=87.5GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=6875, total_len=17450, wall=6.7s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6703, total_len=19527, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5937, total_len=10819, wall=6.0s, peak=87.5GB, mem=77.8GB
#   step 8/244: loss:mean=0.245833, grad_norm=0.4994, lr=1.94e-04
#     micro-batch 0: 4 seqs, max_len=6171, total_len=13558, wall=6.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6672, total_len=20332, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7601, total_len=25972, wall=7.3s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7089, total_len=16477, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7129, total_len=17093, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7146, total_len=17465, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=4846, total_len=14809, wall=5.2s, peak=87.5GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=6903, total_len=16362, wall=6.8s, peak=87.5GB, mem=77.8GB
#   step 9/244: loss:mean=0.220655, grad_norm=0.4914, lr=1.93e-04
#     micro-batch 0: 4 seqs, max_len=3116, total_len=6917, wall=3.8s, peak=87.5GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=3005, total_len=9594, wall=3.8s, peak=87.5GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=6719, total_len=15188, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6892, total_len=15141, wall=6.8s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5694, total_len=16986, wall=5.8s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6527, total_len=21989, wall=6.5s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6487, total_len=16347, wall=6.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6630, total_len=16903, wall=6.5s, peak=87.5GB, mem=77.8GB
#   step 10/244: loss:mean=0.215100, grad_norm=0.5078, lr=1.93e-04
#     micro-batch 0: 4 seqs, max_len=7375, total_len=16610, wall=7.1s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7890, total_len=28575, wall=7.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3318, total_len=8311, wall=4.0s, peak=87.8GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7237, total_len=18270, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=3038, total_len=9570, wall=3.8s, peak=87.8GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=7275, total_len=20804, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7013, total_len=17701, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5822, total_len=20127, wall=5.9s, peak=87.8GB, mem=77.8GB
#   step 11/244: loss:mean=0.227870, grad_norm=0.5526, lr=1.92e-04
#     micro-batch 0: 4 seqs, max_len=6791, total_len=19186, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6664, total_len=17159, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6455, total_len=13674, wall=6.4s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7415, total_len=21362, wall=7.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6207, total_len=15054, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6648, total_len=14091, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6358, total_len=21572, wall=6.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5694, total_len=14695, wall=5.8s, peak=87.8GB, mem=77.8GB
#   step 12/244: loss:mean=0.183275, grad_norm=0.5725, lr=1.91e-04
#     micro-batch 0: 4 seqs, max_len=7435, total_len=22278, wall=7.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7217, total_len=16167, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3512, total_len=10742, wall=4.1s, peak=87.8GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7078, total_len=20291, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7481, total_len=15950, wall=7.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7442, total_len=18487, wall=7.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=4084, total_len=11936, wall=4.5s, peak=87.8GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=4100, total_len=11237, wall=4.5s, peak=87.8GB, mem=77.7GB
#   step 13/244: loss:mean=0.185273, grad_norm=0.5241, lr=1.90e-04
#     micro-batch 0: 4 seqs, max_len=5496, total_len=13846, wall=5.7s, peak=87.8GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=3711, total_len=11076, wall=4.3s, peak=87.8GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=7254, total_len=19600, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=2878, total_len=6583, wall=3.7s, peak=87.8GB, mem=77.6GB
#     micro-batch 4: 4 seqs, max_len=5518, total_len=12907, wall=5.7s, peak=87.8GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=5924, total_len=14964, wall=6.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=3135, total_len=7004, wall=3.9s, peak=87.8GB, mem=77.6GB
#     micro-batch 7: 4 seqs, max_len=5899, total_len=14995, wall=6.0s, peak=87.8GB, mem=77.8GB
#   step 14/244: loss:mean=0.134935, grad_norm=0.4978, lr=1.89e-04
#     micro-batch 0: 4 seqs, max_len=6783, total_len=19133, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6793, total_len=17454, wall=6.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6921, total_len=18578, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6202, total_len=18922, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6348, total_len=13542, wall=6.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7289, total_len=26090, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7221, total_len=22231, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7284, total_len=19242, wall=7.0s, peak=87.8GB, mem=77.8GB
#   step 15/244: loss:mean=0.158559, grad_norm=0.5100, lr=1.89e-04
#     micro-batch 0: 4 seqs, max_len=3913, total_len=10339, wall=4.4s, peak=87.8GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=7622, total_len=19511, wall=7.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3794, total_len=12983, wall=4.3s, peak=87.8GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7426, total_len=21652, wall=7.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7257, total_len=22624, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=3216, total_len=10165, wall=3.9s, peak=87.8GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=6913, total_len=17275, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=4750, total_len=9841, wall=5.1s, peak=87.8GB, mem=77.7GB
#   step 16/244: loss:mean=0.134627, grad_norm=0.5907, lr=1.88e-04
#     micro-batch 0: 4 seqs, max_len=7190, total_len=21895, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7108, total_len=16081, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7168, total_len=16701, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7229, total_len=20755, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6215, total_len=14918, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7386, total_len=14599, wall=7.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6072, total_len=14255, wall=6.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5689, total_len=10485, wall=5.8s, peak=87.8GB, mem=77.8GB
#   step 17/244: loss:mean=0.119377, grad_norm=0.4377, lr=1.87e-04
#     micro-batch 0: 4 seqs, max_len=6708, total_len=11033, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7517, total_len=21679, wall=7.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7030, total_len=22533, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7505, total_len=23973, wall=7.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5971, total_len=14465, wall=6.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7121, total_len=16646, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7136, total_len=13135, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6878, total_len=17479, wall=6.7s, peak=87.8GB, mem=77.8GB
#   step 18/244: loss:mean=0.130276, grad_norm=0.5018, lr=1.86e-04
#     micro-batch 0: 4 seqs, max_len=4265, total_len=11062, wall=4.6s, peak=87.8GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6920, total_len=18102, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6904, total_len=21859, wall=7.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6503, total_len=14137, wall=6.4s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6903, total_len=19698, wall=6.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=4293, total_len=10800, wall=4.7s, peak=87.8GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=4924, total_len=8466, wall=5.2s, peak=87.8GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=4405, total_len=14565, wall=4.8s, peak=87.8GB, mem=77.7GB
#   step 19/244: loss:mean=0.084937, grad_norm=0.3939, lr=1.85e-04
#     micro-batch 0: 4 seqs, max_len=3506, total_len=9289, wall=4.1s, peak=87.8GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=7238, total_len=24192, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=4469, total_len=11271, wall=4.8s, peak=87.8GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6184, total_len=14430, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4823, total_len=13458, wall=5.1s, peak=87.8GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=4804, total_len=9326, wall=5.1s, peak=87.8GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6925, total_len=18284, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7219, total_len=19095, wall=7.0s, peak=87.8GB, mem=77.8GB
#   step 20/244: loss:mean=0.082437, grad_norm=0.3761, lr=1.84e-04
#     micro-batch 0: 4 seqs, max_len=6373, total_len=16754, wall=6.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6467, total_len=11423, wall=6.4s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6198, total_len=15799, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=3936, total_len=8506, wall=4.4s, peak=87.8GB, mem=77.7GB
#     micro-batch 4: 4 seqs, max_len=3148, total_len=10077, wall=3.9s, peak=87.8GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=5935, total_len=18537, wall=6.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6932, total_len=12034, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2904, total_len=5499, wall=3.7s, peak=87.8GB, mem=77.6GB
#   step 21/244: loss:mean=0.067297, grad_norm=0.3904, lr=1.84e-04
#     micro-batch 0: 4 seqs, max_len=3685, total_len=10762, wall=4.2s, peak=87.8GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=7064, total_len=20119, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6855, total_len=18199, wall=6.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7639, total_len=24466, wall=7.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4812, total_len=11814, wall=5.1s, peak=87.8GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6832, total_len=17165, wall=6.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7271, total_len=17218, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5519, total_len=14674, wall=5.7s, peak=87.8GB, mem=77.7GB
#   step 22/244: loss:mean=0.068785, grad_norm=0.3427, lr=1.83e-04
#     micro-batch 0: 4 seqs, max_len=3052, total_len=7386, wall=3.8s, peak=87.8GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7085, total_len=15138, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6559, total_len=14031, wall=6.5s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7145, total_len=23976, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7290, total_len=20325, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=4753, total_len=12449, wall=5.1s, peak=87.8GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6655, total_len=15636, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6238, total_len=12482, wall=6.3s, peak=87.8GB, mem=77.8GB
#   step 23/244: loss:mean=0.063543, grad_norm=0.3503, lr=1.82e-04
#     micro-batch 0: 4 seqs, max_len=2609, total_len=7599, wall=3.5s, peak=87.8GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7250, total_len=17659, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3664, total_len=9966, wall=4.2s, peak=87.8GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6186, total_len=12498, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6827, total_len=20374, wall=6.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6941, total_len=17378, wall=7.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7806, total_len=11744, wall=7.5s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3071, total_len=8109, wall=3.8s, peak=87.8GB, mem=77.6GB
#   step 24/244: loss:mean=0.059948, grad_norm=0.3256, lr=1.81e-04
#     micro-batch 0: 4 seqs, max_len=6713, total_len=20910, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2592, total_len=8924, wall=3.5s, peak=87.8GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=6469, total_len=17562, wall=6.4s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6748, total_len=16845, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7224, total_len=13847, wall=7.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7310, total_len=14504, wall=7.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6792, total_len=10357, wall=6.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7022, total_len=16624, wall=6.8s, peak=87.8GB, mem=77.8GB
#   step 25/244: loss:mean=0.054734, grad_norm=0.3916, lr=1.80e-04
#     micro-batch 0: 4 seqs, max_len=3006, total_len=10898, wall=3.8s, peak=87.8GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7069, total_len=22774, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7023, total_len=16208, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6251, total_len=16643, wall=6.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6495, total_len=18366, wall=6.4s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6032, total_len=10351, wall=6.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7354, total_len=12253, wall=7.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6695, total_len=18682, wall=6.6s, peak=87.8GB, mem=77.8GB
#   step 26/244: loss:mean=0.044490, grad_norm=0.3888, lr=1.80e-04
#     micro-batch 0: 4 seqs, max_len=5509, total_len=11014, wall=5.7s, peak=87.8GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=7471, total_len=21064, wall=7.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6953, total_len=21372, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7376, total_len=17064, wall=7.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4875, total_len=9718, wall=5.2s, peak=87.8GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6481, total_len=13277, wall=6.4s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7011, total_len=14194, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7080, total_len=16253, wall=6.9s, peak=87.8GB, mem=77.8GB
#   step 27/244: loss:mean=0.038532, grad_norm=0.3552, lr=1.79e-04
#     micro-batch 0: 4 seqs, max_len=6771, total_len=11068, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6700, total_len=14047, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6826, total_len=17790, wall=6.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6593, total_len=14529, wall=6.5s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7196, total_len=19585, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7560, total_len=18680, wall=7.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6724, total_len=21401, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7060, total_len=17741, wall=6.9s, peak=87.8GB, mem=77.8GB
#   step 28/244: loss:mean=0.036515, grad_norm=0.4629, lr=1.78e-04
#     micro-batch 0: 4 seqs, max_len=4199, total_len=13313, wall=4.6s, peak=87.8GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6077, total_len=14081, wall=6.1s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6658, total_len=14751, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7578, total_len=15783, wall=7.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7278, total_len=17368, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6670, total_len=14972, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6746, total_len=18669, wall=6.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3989, total_len=8958, wall=4.5s, peak=87.8GB, mem=77.7GB
#   step 29/244: loss:mean=0.025702, grad_norm=0.4006, lr=1.77e-04
#     micro-batch 0: 4 seqs, max_len=6175, total_len=19679, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2801, total_len=10046, wall=4.6s, peak=87.8GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=7118, total_len=19063, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7527, total_len=19435, wall=7.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4461, total_len=11051, wall=4.8s, peak=87.8GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6893, total_len=11874, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6314, total_len=16918, wall=6.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6527, total_len=20659, wall=6.4s, peak=87.8GB, mem=77.8GB
#   step 30/244: loss:mean=0.024539, grad_norm=0.2545, lr=1.76e-04
#     micro-batch 0: 4 seqs, max_len=7196, total_len=19321, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5768, total_len=11698, wall=5.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7085, total_len=12938, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7056, total_len=21118, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5984, total_len=17729, wall=6.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6271, total_len=15368, wall=6.3s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6993, total_len=13780, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5590, total_len=11409, wall=5.8s, peak=87.8GB, mem=77.8GB
#   step 31/244: loss:mean=0.019497, grad_norm=0.2642, lr=1.75e-04
#     micro-batch 0: 4 seqs, max_len=6013, total_len=16450, wall=6.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6914, total_len=12526, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3666, total_len=9294, wall=4.2s, peak=87.8GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6135, total_len=14877, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7290, total_len=16626, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6613, total_len=13158, wall=6.5s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7238, total_len=18084, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6451, total_len=18078, wall=6.4s, peak=87.8GB, mem=77.8GB
#   step 32/244: loss:mean=0.018926, grad_norm=0.2678, lr=1.75e-04
#     micro-batch 0: 4 seqs, max_len=7100, total_len=19785, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6933, total_len=21888, wall=6.7s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7520, total_len=23586, wall=7.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7092, total_len=17495, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7141, total_len=18488, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6614, total_len=19320, wall=6.5s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7191, total_len=21200, wall=7.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5684, total_len=11062, wall=5.8s, peak=87.8GB, mem=77.8GB
#   step 33/244: loss:mean=0.021647, grad_norm=0.2635, lr=1.74e-04
#     micro-batch 0: 4 seqs, max_len=3988, total_len=13044, wall=4.4s, peak=87.8GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=5722, total_len=11693, wall=5.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6926, total_len=17533, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6196, total_len=21177, wall=6.2s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5765, total_len=13420, wall=5.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7045, total_len=21256, wall=6.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7037, total_len=19386, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5527, total_len=14572, wall=5.7s, peak=87.8GB, mem=77.7GB
#   step 34/244: loss:mean=0.015202, grad_norm=0.2152, lr=1.73e-04
#     micro-batch 0: 4 seqs, max_len=6949, total_len=16275, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5935, total_len=16292, wall=6.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5965, total_len=12367, wall=6.0s, peak=87.8GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=5856, total_len=14093, wall=5.9s, peak=87.8GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6692, total_len=15223, wall=7.6s, peak=87.8GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6913, total_len=18350, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=3959, total_len=11336, wall=4.5s, peak=87.8GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=6912, total_len=15684, wall=6.8s, peak=87.8GB, mem=77.8GB
#   step 35/244: loss:mean=0.011629, grad_norm=0.1667, lr=1.72e-04
#     micro-batch 0: 4 seqs, max_len=5751, total_len=14748, wall=5.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6961, total_len=20279, wall=6.8s, peak=87.8GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7998, total_len=22237, wall=7.6s, peak=87.9GB, mem=77.9GB
#     micro-batch 3: 4 seqs, max_len=5673, total_len=9779, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7211, total_len=17587, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7666, total_len=21408, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6250, total_len=14890, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=4073, total_len=10743, wall=4.5s, peak=87.9GB, mem=77.7GB
#   step 36/244: loss:mean=0.016222, grad_norm=0.1920, lr=1.71e-04
#     micro-batch 0: 4 seqs, max_len=7424, total_len=18341, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6318, total_len=12318, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3072, total_len=6081, wall=3.8s, peak=87.9GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=6861, total_len=15674, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6003, total_len=13971, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7060, total_len=20021, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6622, total_len=21257, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2405, total_len=6064, wall=3.3s, peak=87.9GB, mem=77.6GB
#   step 37/244: loss:mean=0.012442, grad_norm=0.2032, lr=1.70e-04
#     micro-batch 0: 4 seqs, max_len=4090, total_len=11128, wall=4.5s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6700, total_len=13841, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3558, total_len=10059, wall=4.2s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7475, total_len=18568, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5788, total_len=12435, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6693, total_len=18792, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6600, total_len=20712, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7540, total_len=24880, wall=7.2s, peak=87.9GB, mem=77.8GB
#   step 38/244: loss:mean=0.010889, grad_norm=0.1594, lr=1.70e-04
#     micro-batch 0: 4 seqs, max_len=7335, total_len=19621, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5937, total_len=15783, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7415, total_len=14021, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7236, total_len=24126, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7416, total_len=14583, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7180, total_len=13464, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=4072, total_len=8980, wall=4.5s, peak=87.9GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=7372, total_len=22098, wall=7.1s, peak=87.9GB, mem=77.8GB
#   step 39/244: loss:mean=0.012156, grad_norm=0.1741, lr=1.69e-04
#     micro-batch 0: 4 seqs, max_len=5925, total_len=16776, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5988, total_len=18883, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6041, total_len=15814, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7014, total_len=21448, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6031, total_len=17876, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6667, total_len=20067, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7603, total_len=13985, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5986, total_len=15336, wall=6.0s, peak=87.9GB, mem=77.8GB
#   step 40/244: loss:mean=0.006623, grad_norm=0.1151, lr=1.68e-04
#     micro-batch 0: 4 seqs, max_len=6978, total_len=14462, wall=7.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7173, total_len=9410, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7512, total_len=25022, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7397, total_len=23687, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6660, total_len=23339, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7107, total_len=14493, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6947, total_len=15265, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5669, total_len=12920, wall=5.8s, peak=87.9GB, mem=77.8GB
#   step 41/244: loss:mean=0.012687, grad_norm=0.1876, lr=1.67e-04
#     micro-batch 0: 4 seqs, max_len=6059, total_len=15892, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7338, total_len=24501, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7474, total_len=22684, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7426, total_len=17130, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2650, total_len=6118, wall=3.5s, peak=87.9GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=6337, total_len=15660, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7163, total_len=11755, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7637, total_len=21681, wall=7.3s, peak=87.9GB, mem=77.8GB
#   step 42/244: loss:mean=0.008854, grad_norm=0.1652, lr=1.66e-04
#     micro-batch 0: 4 seqs, max_len=7327, total_len=13214, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6830, total_len=15563, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7716, total_len=14018, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=4417, total_len=12465, wall=4.8s, peak=87.9GB, mem=77.7GB
#     micro-batch 4: 4 seqs, max_len=3728, total_len=9686, wall=4.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=7368, total_len=15787, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7812, total_len=22957, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7512, total_len=24183, wall=7.2s, peak=87.9GB, mem=77.8GB
#   step 43/244: loss:mean=0.008270, grad_norm=0.1432, lr=1.66e-04
#     micro-batch 0: 4 seqs, max_len=7482, total_len=26974, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7519, total_len=15401, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7274, total_len=11404, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7316, total_len=21429, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6913, total_len=15801, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7407, total_len=24251, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7141, total_len=14633, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7524, total_len=15792, wall=7.2s, peak=87.9GB, mem=77.8GB
#   step 44/244: loss:mean=0.010802, grad_norm=0.1660, lr=1.65e-04
#     micro-batch 0: 4 seqs, max_len=7816, total_len=18144, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6876, total_len=11036, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7107, total_len=20442, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7250, total_len=18255, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7287, total_len=20783, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5617, total_len=14466, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7687, total_len=16579, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=4323, total_len=12132, wall=4.7s, peak=87.9GB, mem=77.7GB
#   step 45/244: loss:mean=0.007762, grad_norm=0.1375, lr=1.64e-04
#     micro-batch 0: 4 seqs, max_len=6699, total_len=12781, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7344, total_len=20798, wall=8.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6957, total_len=15994, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=5825, total_len=14889, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6162, total_len=13905, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5669, total_len=11533, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6778, total_len=16334, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6700, total_len=15712, wall=6.6s, peak=87.9GB, mem=77.8GB
#   step 46/244: loss:mean=0.007269, grad_norm=0.1621, lr=1.63e-04
#     micro-batch 0: 4 seqs, max_len=6021, total_len=10844, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=3499, total_len=9581, wall=4.1s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=6857, total_len=19024, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7211, total_len=11756, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7349, total_len=11871, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7078, total_len=11701, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6118, total_len=11242, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6443, total_len=15465, wall=6.4s, peak=87.9GB, mem=77.8GB
#   step 47/244: loss:mean=0.005875, grad_norm=0.2064, lr=1.62e-04
#     micro-batch 0: 4 seqs, max_len=4364, total_len=11007, wall=4.7s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6761, total_len=15717, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=4975, total_len=11388, wall=5.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7030, total_len=15975, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7357, total_len=20787, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5589, total_len=14630, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6763, total_len=14757, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7634, total_len=21596, wall=7.3s, peak=87.9GB, mem=77.8GB
#   step 48/244: loss:mean=0.004618, grad_norm=0.1204, lr=1.61e-04
#     micro-batch 0: 4 seqs, max_len=6370, total_len=14813, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7649, total_len=12679, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3838, total_len=11985, wall=4.4s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=5038, total_len=10525, wall=5.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 4: 4 seqs, max_len=6359, total_len=14463, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5946, total_len=14556, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6414, total_len=19537, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3692, total_len=10672, wall=4.3s, peak=87.9GB, mem=77.7GB
#   step 49/244: loss:mean=0.004259, grad_norm=0.1402, lr=1.61e-04
#     micro-batch 0: 4 seqs, max_len=2861, total_len=7109, wall=3.7s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=5069, total_len=11558, wall=5.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=6962, total_len=14817, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7154, total_len=18376, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6898, total_len=13307, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6884, total_len=22872, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7434, total_len=17490, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7343, total_len=18425, wall=7.1s, peak=87.9GB, mem=77.8GB
#   step 50/244: loss:mean=0.008159, grad_norm=0.1838, lr=1.60e-04
#     micro-batch 0: 4 seqs, max_len=5753, total_len=16623, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6569, total_len=13998, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6264, total_len=18430, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7047, total_len=16686, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7416, total_len=16811, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7281, total_len=21831, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7239, total_len=17018, wall=8.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=4597, total_len=12888, wall=5.0s, peak=87.9GB, mem=77.7GB
#   step 51/244: loss:mean=0.004673, grad_norm=0.1242, lr=1.59e-04
#     micro-batch 0: 4 seqs, max_len=7135, total_len=13693, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5695, total_len=16863, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7295, total_len=19005, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6354, total_len=13048, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7465, total_len=23359, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7243, total_len=15963, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=5720, total_len=16838, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7221, total_len=23434, wall=7.0s, peak=87.9GB, mem=77.8GB
#   step 52/244: loss:mean=0.003798, grad_norm=39254560.0000, lr=1.58e-04
#     micro-batch 0: 4 seqs, max_len=7202, total_len=16440, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=3907, total_len=8493, wall=4.4s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=7515, total_len=16771, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6782, total_len=20867, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5860, total_len=8350, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5706, total_len=11133, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6848, total_len=22436, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6024, total_len=10103, wall=6.1s, peak=87.9GB, mem=77.8GB
#   step 53/244: loss:mean=0.004921, grad_norm=0.1339, lr=1.57e-04
#     micro-batch 0: 4 seqs, max_len=7212, total_len=15842, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6561, total_len=14547, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6246, total_len=14344, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7369, total_len=18375, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7100, total_len=18786, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5676, total_len=17938, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7017, total_len=16526, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7100, total_len=16410, wall=6.9s, peak=87.9GB, mem=77.8GB
#   step 54/244: loss:mean=0.006483, grad_norm=0.1523, lr=1.57e-04
#     micro-batch 0: 4 seqs, max_len=2858, total_len=9854, wall=3.7s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=5750, total_len=12310, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6766, total_len=21346, wall=6.7s, peak=87.9GB, mem=77.8GB
# ...
#     micro-batch 6: 4 seqs, max_len=5200, total_len=16060, wall=5.5s, peak=87.9GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=7628, total_len=15426, wall=7.3s, peak=87.9GB, mem=77.8GB
#   step 225/244: loss:mean=0.009622, grad_norm=0.2066, lr=1.64e-05
#     micro-batch 0: 4 seqs, max_len=6118, total_len=12827, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6695, total_len=24615, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7176, total_len=19871, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7048, total_len=23545, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6646, total_len=19718, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=2717, total_len=8577, wall=3.6s, peak=87.9GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=7276, total_len=20792, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3731, total_len=10595, wall=4.3s, peak=87.9GB, mem=77.7GB
#   step 226/244: loss:mean=0.008495, grad_norm=0.1983, lr=1.56e-05
#     micro-batch 0: 4 seqs, max_len=7048, total_len=20493, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2846, total_len=8909, wall=3.7s, peak=87.9GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=6910, total_len=18762, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7211, total_len=19253, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6003, total_len=19882, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7407, total_len=18431, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6528, total_len=15755, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7000, total_len=15277, wall=6.8s, peak=87.9GB, mem=77.8GB
#   step 227/244: loss:mean=0.009300, grad_norm=0.2079, lr=1.48e-05
#     micro-batch 0: 4 seqs, max_len=4500, total_len=12483, wall=4.9s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=5780, total_len=12404, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7445, total_len=18125, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6495, total_len=17036, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4584, total_len=9773, wall=5.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=7493, total_len=19747, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=5964, total_len=14172, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6754, total_len=12893, wall=6.7s, peak=87.9GB, mem=77.8GB
#   step 228/244: loss:mean=0.006550, grad_norm=0.1560, lr=1.39e-05
#     micro-batch 0: 4 seqs, max_len=6910, total_len=19440, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=4874, total_len=11620, wall=5.2s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=3326, total_len=11800, wall=4.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7027, total_len=16782, wall=7.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4512, total_len=11264, wall=4.9s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6779, total_len=23275, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7220, total_len=13690, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7311, total_len=19193, wall=7.1s, peak=87.9GB, mem=77.8GB
#   step 229/244: loss:mean=0.006777, grad_norm=0.1495, lr=1.31e-05
#     micro-batch 0: 4 seqs, max_len=4385, total_len=8409, wall=4.8s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6167, total_len=19060, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5791, total_len=16276, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6003, total_len=14264, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6951, total_len=14679, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6212, total_len=16865, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=5713, total_len=12792, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3964, total_len=8518, wall=4.5s, peak=87.9GB, mem=77.7GB
#   step 230/244: loss:mean=0.002866, grad_norm=0.0673, lr=1.23e-05
#     micro-batch 0: 4 seqs, max_len=7503, total_len=20039, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7173, total_len=16110, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6071, total_len=10888, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6810, total_len=14487, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6686, total_len=17626, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=4159, total_len=9550, wall=4.6s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6857, total_len=16982, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6635, total_len=16607, wall=6.6s, peak=87.9GB, mem=77.8GB
#   step 231/244: loss:mean=0.007524, grad_norm=0.1816, lr=1.15e-05
#     micro-batch 0: 4 seqs, max_len=4087, total_len=13797, wall=4.5s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=3659, total_len=6767, wall=4.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=7490, total_len=17489, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7625, total_len=13766, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7074, total_len=16333, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7329, total_len=18414, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7250, total_len=17122, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5749, total_len=13203, wall=5.9s, peak=87.9GB, mem=77.8GB
#   step 232/244: loss:mean=0.008062, grad_norm=0.1525, lr=1.07e-05
#     micro-batch 0: 4 seqs, max_len=7493, total_len=18266, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7485, total_len=12263, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3293, total_len=6022, wall=4.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6931, total_len=18120, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5649, total_len=10988, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=4266, total_len=11321, wall=4.7s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6566, total_len=17660, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6266, total_len=13337, wall=6.3s, peak=87.9GB, mem=77.8GB
#   step 233/244: loss:mean=0.007055, grad_norm=0.1695, lr=9.84e-06
#     micro-batch 0: 4 seqs, max_len=6875, total_len=11867, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6992, total_len=22523, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7214, total_len=25269, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6339, total_len=10867, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7359, total_len=12294, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7481, total_len=23505, wall=8.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7026, total_len=19476, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6986, total_len=18185, wall=6.8s, peak=87.9GB, mem=77.8GB
#   step 234/244: loss:mean=0.011263, grad_norm=0.2142, lr=9.02e-06
#     micro-batch 0: 4 seqs, max_len=6765, total_len=16839, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7191, total_len=18984, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7377, total_len=24067, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6788, total_len=17370, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5961, total_len=14681, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6542, total_len=12851, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=5009, total_len=9446, wall=5.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=6529, total_len=18875, wall=6.5s, peak=87.9GB, mem=77.8GB
#   step 235/244: loss:mean=0.009688, grad_norm=0.2409, lr=8.20e-06
#     micro-batch 0: 4 seqs, max_len=7620, total_len=14606, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7342, total_len=18958, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5674, total_len=10247, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6268, total_len=17198, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=3594, total_len=6409, wall=4.2s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6913, total_len=16276, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6932, total_len=13115, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6761, total_len=14591, wall=6.7s, peak=87.9GB, mem=77.8GB
#   step 236/244: loss:mean=0.007862, grad_norm=0.1619, lr=7.38e-06
#     micro-batch 0: 4 seqs, max_len=7237, total_len=16531, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6961, total_len=23046, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=4490, total_len=10282, wall=4.9s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7352, total_len=19135, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5197, total_len=11958, wall=5.5s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=7579, total_len=20341, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7519, total_len=23820, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7307, total_len=22783, wall=7.1s, peak=87.9GB, mem=77.8GB
#   step 237/244: loss:mean=0.008634, grad_norm=0.1816, lr=6.56e-06
#     micro-batch 0: 4 seqs, max_len=5373, total_len=16829, wall=5.5s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=5935, total_len=17336, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5926, total_len=17534, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7346, total_len=16980, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7548, total_len=17167, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6988, total_len=13451, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7356, total_len=21676, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=4285, total_len=13252, wall=4.7s, peak=87.9GB, mem=77.7GB
#   step 238/244: loss:mean=0.005879, grad_norm=0.1332, lr=5.74e-06
#     micro-batch 0: 4 seqs, max_len=3367, total_len=9030, wall=4.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=4612, total_len=11490, wall=5.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=7132, total_len=19344, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6807, total_len=18934, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7185, total_len=19354, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6684, total_len=17635, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=4266, total_len=10098, wall=4.7s, peak=87.9GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=7009, total_len=12526, wall=7.8s, peak=87.9GB, mem=77.8GB
#   step 239/244: loss:mean=0.007177, grad_norm=0.1455, lr=4.92e-06
#     micro-batch 0: 4 seqs, max_len=5748, total_len=15015, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6757, total_len=13148, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7342, total_len=21088, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7287, total_len=23153, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6682, total_len=15026, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7714, total_len=22119, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7310, total_len=16156, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7445, total_len=22461, wall=7.1s, peak=87.9GB, mem=77.8GB
#   step 240/244: loss:mean=0.007961, grad_norm=0.2177, lr=4.10e-06
#     micro-batch 0: 4 seqs, max_len=7243, total_len=14229, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7158, total_len=14457, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7601, total_len=20144, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6795, total_len=16929, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2648, total_len=6729, wall=3.5s, peak=87.9GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=7118, total_len=23231, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7473, total_len=18811, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6014, total_len=10402, wall=6.1s, peak=87.9GB, mem=77.8GB
#   step 241/244: loss:mean=0.009838, grad_norm=0.2286, lr=3.28e-06
#     micro-batch 0: 4 seqs, max_len=2659, total_len=4789, wall=3.5s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=6807, total_len=21360, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6747, total_len=17267, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=5949, total_len=12902, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5940, total_len=17039, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=3907, total_len=8028, wall=4.4s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=7114, total_len=21782, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=4156, total_len=11014, wall=4.6s, peak=87.9GB, mem=77.7GB
#   step 242/244: loss:mean=0.006737, grad_norm=0.1358, lr=2.46e-06
#     micro-batch 0: 4 seqs, max_len=3563, total_len=13133, wall=4.1s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=7570, total_len=21466, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3292, total_len=9710, wall=4.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7242, total_len=18394, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7163, total_len=18492, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7231, total_len=19688, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7407, total_len=12674, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=4106, total_len=11933, wall=4.6s, peak=87.9GB, mem=77.7GB
#   step 243/244: loss:mean=0.010035, grad_norm=0.2306, lr=1.64e-06
#     micro-batch 0: 4 seqs, max_len=6709, total_len=13367, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5044, total_len=13337, wall=5.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=4264, total_len=13587, wall=4.7s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7243, total_len=23531, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4329, total_len=11135, wall=4.7s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=4380, total_len=12338, wall=4.8s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6440, total_len=15475, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=4716, total_len=12018, wall=5.1s, peak=87.9GB, mem=77.7GB
#   step 244/244: loss:mean=0.005786, grad_norm=0.1088, lr=8.20e-07
#
# Training complete. Peak VRAM: 87.9 GB
# /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:279: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# Wrote submission.zip
# Training complete.
